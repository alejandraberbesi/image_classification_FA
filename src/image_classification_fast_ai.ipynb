# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandraberbesi/image_classification_FA/blob/master/image_classification_fast_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai  import *
from fastai.vision import *
